# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import MultinomialNB,GaussianNB
from sklearn.model_selection import train_test_split

# %%
h=['Number of times pregnant','Plasma glucose concentration a 2 hours in an oral glucose tolerance test','Diastolic blood pressure (mm Hg)','Triceps skin fold thickness (mm)','2-Hour serum insulin (mu U/ml)','Body mass index (weight in kg/(height in m)^2)','Diabetes pedigree function','Age (years)','Class variable (0 or 1)']

# %%
df=pd.read_csv('pima-indians-diabetes.csv',skiprows=9)

# %%
df.to_csv("new.csv",header=h,index=False)

# %%
df=pd.read_csv('new.csv')
df
# Out:
#      Number of times pregnant  \
# 0                           1
# 1                           8
# 2                           1
# 3                           0
# 4                           5
# ..                        ...
# 762                        10
# 763                         2
# 764                         5
# 765                         1
# 766                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                   85
# 1                                                  183
# 2                                                   89
# 3                                                  137
# 4                                                  116
# ..                                                 ...
# 762                                                101
# 763                                                122
# 764                                                121
# ...

# %%
x=df.drop('Class variable (0 or 1)',axis=1)
x
# Out:
#      Number of times pregnant  \
# 0                           1
# 1                           8
# 2                           1
# 3                           0
# 4                           5
# ..                        ...
# 762                        10
# 763                         2
# 764                         5
# 765                         1
# 766                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                   85
# 1                                                  183
# 2                                                   89
# 3                                                  137
# 4                                                  116
# ..                                                 ...
# 762                                                101
# 763                                                122
# 764                                                121
# ...

# %%
y=df['Class variable (0 or 1)']
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 762    0
# 763    0
# 764    0
# 765    1
# 766    0
# Name: Class variable (0 or 1), Length: 767, dtype: int64

# %%
tr_x,ts_x,tr_y,ts_y=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
lm=MultinomialNB().fit(tr_x,tr_y)

# %%
lm.score(ts_x,ts_y)
# Out:
# 0.6041666666666666

# %%
gm=GaussianNB().fit(tr_x,tr_y)
gm.score(ts_x,ts_y)
# Out:
# 0.7916666666666666
