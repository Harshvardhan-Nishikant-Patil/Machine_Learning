# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
df=pd.read_csv('Order2.csv')
df
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
ds=[]
for i in range(0,205):
    ds.append([str(df.values[i,j]) for j in range(0,5)])

# %%
t1=apriori(ds,min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
t1_n=list(t1)

# %%
print(len(t1_n))
# Out:
# 214

# %%
t1_n
# Out:
# [RelationRecord(items=frozenset({'almonds', 'burgers'}), support=0.00975609756097561, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'burgers'}), confidence=0.6666666666666666, lift=5.942028985507246)]),
#  RelationRecord(items=frozenset({'almonds', 'cookies'}), support=0.004878048780487805, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'cookies'}), confidence=0.3333333333333333, lift=4.555555555555555)]),
#  RelationRecord(items=frozenset({'almonds', 'eggs'}), support=0.00975609756097561, ordered_statistics=[OrderedStatistic(items_base=frozenset({'almonds'}), items_add=frozenset({'eggs'}), confidence=0.6666666666666666, lift=4.019607843137255)]),
# ...

# %%
t2=list(t1_n)

# %%
def inspect(t2):
    lhs         = [tuple(df[1][0])[0] for df in t2]
    rhs         = [tuple(df[1][0])[0] for df in t2]
    support    = [df[1] for df in t2]
    confidence = [df[1][0] for df in t2]
    lift       = [df[1][0] for df in t2]
    return list(zip(lhs, rhs, support, confidence, lift))
output_DataFrame = pd.DataFrame(inspect(df), columns = ['Left_Hand_Side', 'Right_Hand_Side', 'Support', 'Confidence', 'Lift'])

# %%
output_DataFrame
# Out:
#    Left_Hand_Side Right_Hand_Side Support Confidence Lift
# 0               h               h       h          h    h
# 1               l               l       l          l    l
# 2               v               v       v          v    v
# 3               e               e       e          e    e
# 4               r               r       r          r    r
# 5               h               h       h          h    h
# 6               a               a       a          a    a
# 7               o               o       o          o    o
# 8               n               n       n          n    n
# 9               o               o       o          o    o
# 10              o               o       o          o    o
# 11              r               r       r          r    r
# 12              o               o       o          o    o
# 13              a               a       a          a    a
# 14              i               i       i          i    i
# ...
